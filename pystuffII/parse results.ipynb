# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
def id2el(Id):
    """Constructs the graph associated to the number Id.
    """
    el = []

    Id = int(Id)

    mask = int(1)
    u = int(0)
    v = int(1)
    while u < 10:
        if (Id & mask):
            el.append((u,v))
    
        mask = (mask << int(1))
        v += int(1)
    
        if v > 10:
            u += 1
            v = u+1
    return el
id2G  = lambda Id : Graph(id2el(np.uint64(Id)))


def G2id(G):
    for ID in Xber:
        if nx.is_isomorphic(G, id2G(ID)):
            return ID
    return None

# %%
with open("/home/alvaro/Dropbox/PROLIFERACION/pystuff/ventilador/jobs.pickle", "rb") as infile:
    Xber = pickle.load(infile)
IDs = [ ID for ID in Xber.keys() if id2G(ID).order()==6]
Xber = {ID:Xber[ID] for ID in IDs}

# %%
remaining =  list((i,G) for i,G in enumerate(G for G in graphs(6) if G.is_connected()))
asig = {}
for ID in IDs:
    Gp = id2G(ID)
    for k,(i,G) in enumerate(remaining):
        if G.is_isomorphic(Gp):
            asig[ID] = (i,G)
            del remaining[k]
            break
    else:
        raise "Error"

# %%
r,p = var("r, p")
xx = []
y = []
for k in range(10,100):
    xx.append((k,100))
    y.append((k,10))
xx.extend(y)
del y
rvals = [ a[0]/a[1] for a in xx ]
del xx

# %%
with open("bernoulli_unconditional_mean_time.txt", "wt") as outfile:
    for ID in IDs:
        print(ID)
        i,G = asig[ID]
        sage.repl.load.load(f"{i}.sage", globals())

        line = [ (bernoulli_unconditional_mean_time_from1(r=vr).factor()(p=vp)) for vr, vp in zip(rvals, Xber[ID]) ]
        print(ID, ", ".join(str(x) for x in line), file=outfile, sep=", ")
# Out:
# 17450410000
# 17585680408
# 17586207760
# 17584627728
# 17450405896
# 405811224
# 17586200593
# 17584623620
# 17584628752
# 17450930185
# 17585679376
# 17449355267
# 17586204696
# 17586200577
# 17585676304
# 17315667984
# 17450409992
# 17586200584
# 17585676305
# 17586207768
# 17586200592
# 270016520
# 17585678355
# 406335513
# 406331400
# 17586204697
# 17585681412
# 17585680388
# 17585680400
# 17586206722
# 17450405892
# 17449889798
# 17585678348
# 17450930177
# 17450934280
# 17586206736
# 17585676289
# 17316192260
# 17450932235
# 406338584
# 17585676296
# 17585678352
# 406331401
# 17585679375
# 17586206747
# 17586207774
# 17586207775
# 405807112
# 17586206744
# 17449885705
# 17450408974
# 17586204678
# 17584103440
# 17586200585
# 17449886732
# 17586206746
# 17586206748
# 17586207772
# 17586204679
# 406335512
# 17584628748
# 270020632
# 17183553564
# 17586204688
# 17451989020
# 17449889816
# 406337562
# 17585678346
# 17182496792
# 405811216
# 17449356304
# 17586204692
# 17450411020
# ...

# %%
print(moran_unconditional_mean_time_from1)
print(moran_conditional_mean_time_from1)
print(bernoulli_unconditional_mean_time_from1)
print(bernoulli_conditional_mean_time_from1)
# Out:
# 1/2*(54375*r^9 + 317250*r^8 + 488550*r^7 + 576965*r^6 + 480627*r^5 + 447340*r^4 + 341050*r^3 + 307875*r^2 + 188750*r + 131250)/(625*r^9 + 3625*r^8 + 3275*r^7 + 4395*r^6 + 3376*r^5 + 4400*r^4 + 3375*r^3 + 4375*r^2 + 3125*r + 3125)
# 1/2*(271875*r^9 + 546875*r^8 + 997500*r^7 + 1093375*r^6 + 1290475*r^5 + 1135127*r^4 + 1081530*r^3 + 669525*r^2 + 356500*r + 31250)/(3125*r^9 + 3125*r^8 + 4375*r^7 + 3375*r^6 + 4400*r^5 + 3376*r^4 + 4395*r^3 + 3275*r^2 + 3625*r + 625)
# 1/3*(40*p^2*r^3 + 125*p^2*r^2 + 238*p*r^2 + 815*p*r + 252*r + 1260)/(5*p^3*r^3 + 26*p^2*r^2 + 9*p*r + 20)
# 1/3*(40*p^2*r^3 + 125*p^2*r^2 + 243*p*r^2 + 825*p*r + 277*r + 1310)/(5*p^3*r^3 + 26*p^2*r^2 + 9*p*r + 20)

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [45], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined
