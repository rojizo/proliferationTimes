# %%
r,N,j = var("r,N,j")

# %%
f = (N-1) / (r+N-1) / (r^(N-1)-1)
show(f)
# Out:
# (N - 1)/((N + r - 1)*(r^(N - 1) - 1))

# %%
Gj = (r^j-1) * (r^(N-j)-1) / (r-1) * (r*j+N-j) / (j * (N-j))
show(Gj)
show(diff(Gj, r).factor())
show(diff(Gj, r).factor().subs({N: 4}))
# Out:
# (j*r + N - j)*(r^(N - j) - 1)*(r^j - 1)/((N - j)*j*(r - 1))
# (N*j*r^(N + j + 2) + N^2*r^(N + j + 1) - 2*N*j*r^(N + j + 1) - N^2*r^(N + j) + N*j*r^(N + j) - N*j*r^(N + 2) + j^2*r^(N + 2) - N^2*r^(N + 1) + 3*N*j*r^(N + 1) - 2*j^2*r^(N + 1) + N^2*r^N - 2*N*j*r^N + j^2*r^N + N*j*r^(2*j) - j^2*r^(2*j) - j^2*r^(2*j + 2) - N*j*r^(2*j + 1) + 2*j^2*r^(2*j + 1) - N*r^(N + j + 1) + N*r^(N + 1) + N*r^(2*j + 1) - N*r^(j + 1))*r^(-j - 1)/((N - j)*j*(r - 1)^2)
# -(j^2*r^6 - 2*j^2*r^5 - 4*j*r^6 + j^2*r^4 + 12*j*r^5 - 8*j*r^4 - 12*r^5 + 16*r^4 - j^2*r^(2*j) - j^2*r^(2*j + 2) + 2*j^2*r^(2*j + 1) + 4*j*r^(2*j) - 4*j*r^(2*j + 1) + 4*j*r^(j + 6) - 8*j*r^(j + 5) + 4*j*r^(j + 4) + 4*r^(2*j + 1) + 12*r^(j + 5) - 16*r^(j + 4) - 4*r^(j + 1))*r^(-j - 1)/((j - 4)*j*(r - 1)^2)

# %%
df = diff(f,r).factor()#.subs({N:10})
show(df)
show(df.subs({N:4}))
# Out:
# -(N^2*r^N + N*r^(N + 1) - 2*N*r^N - r^2 + r^N)*(N - 1)/((N + r - 1)^2*(r^N - r)^2)
# -3*(4*r^5 + 9*r^4 - r^2)/((r^4 - r)^2*(r + 3)^2)

# %%
e = -(N^2*r^(N + 1) - N^2*r^N - N*r^(2*N) + N*r^(N + 2) - 2*N*r^(N + 1) + 2*N*r^N + r^2 + r^(2*N) - r^(N + 2) - r^N)

# %%
show(e.factor())
# Out:
# -N^2*r^(N + 1) + N^2*r^N + N*r^(2*N) - N*r^(N + 2) + 2*N*r^(N + 1) - 2*N*r^N - r^2 - r^(2*N) + r^(N + 2) + r^N

# %%
df.subs({N:3})
# Out:
# 6*r^2/((r^2 - 1)*(r + 2)) - 4*(r^3 - 1)*r/((r^2 - 1)^2*(r + 2)) - 2*(r^3 - 1)/((r^2 - 1)*(r + 2)^2)

# %%
(N-1) * N *r ^(N-1) * (N+r-1) * (r^(N-1)-1)
# Out:
# (N + r - 1)*(N - 1)*N*(r^(N - 1) - 1)*r^(N - 1)
